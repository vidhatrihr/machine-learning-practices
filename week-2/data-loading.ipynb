# %%
import pandas as pd
from sklearn.datasets import load_iris

# %%
data = load_iris()
type(data)
isinstance(data, dict)
data.keys()
# Out:
# sklearn.utils._bunch.Bunch
# True
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
data.feature_names
data.target_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
type(data.data)
type(data.target)
# Out:
# numpy.ndarray
# numpy.ndarray

# %%
data.data.shape
data.target.shape
# Out:
# (150, 4)
# (150,)

# %%
data.data[:4]
data.target[:4]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2]])
# array([0, 0, 0, 0])

# %% [markdown]
# ## Load as DataFrame

# %%
df = pd.DataFrame(data.data, columns=data.feature_names)
df.head()
df.shape
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# (150, 4)

# %%
data = load_iris(as_frame=True)
data.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
type(data.data)
type(data.target)
# Out:
# pandas.core.frame.DataFrame
# pandas.core.series.Series

# %%
data.data.head()
data.data.shape
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# (150, 4)

# %%
data.target.head()
data.target.shape
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: target, dtype: int64
# (150,)

# %% [markdown]
# ## Directly obtain the feature matrix (X) and target vector (y)

# %%
X, y = load_iris(return_X_y=True)
type(X)
type(y)
# Out:
# numpy.ndarray
# numpy.ndarray

# %%
X.shape
y.shape
# Out:
# (150, 4)
# (150,)
