# %%
import pandas as pd

# %%
data = pd.read_csv('data/GA_2_dataset.csv')
df = pd.DataFrame(data)
df.head()
# Out:
#    PlayerID   Age  Gender Location   GameGenre  PlayTimeHours  \
# 0     35900  37.0    Male    Other    Strategy      23.929404
# 1     27085  25.0    Male      NaN      Action      22.755168
# 2     39595  24.0  Female   Europe  Simulation      19.505292
# 3     37440  26.0  Female   Europe         RPG      11.009645
# 4     22882  17.0  Female      USA         RPG       0.581039
#
#    InGamePurchases GameDifficulty  SessionsPerWeek  AvgSessionDurationMinutes  \
# 0              NaN           Hard                3                        124
# 1              1.0           Easy               14                         84
# 2              0.0           Hard                3                        172
# 3              NaN            NaN                3                         83
# 4              1.0         Medium                5                        163
#
#    PlayerLevel  AchievementsUnlocked EngagementLevel
# 0           99                    18          Medium
# 1           84                    12          Medium
# 2            9                    18          Medium
# 3           36                    43             Low
# 4            9                    24          Medium

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   PlayerID                   10000 non-null  int64
#  1   Age                        9200 non-null   float64
#  2   Gender                     10000 non-null  object
#  3   Location                   9202 non-null   object
#  4   GameGenre                  10000 non-null  object
#  5   PlayTimeHours              10000 non-null  float64
#  6   InGamePurchases            9107 non-null   float64
#  7   GameDifficulty             9154 non-null   object
#  8   SessionsPerWeek            10000 non-null  int64
#  9   AvgSessionDurationMinutes  10000 non-null  int64
#  10  PlayerLevel                10000 non-null  int64
#  11  AchievementsUnlocked       10000 non-null  int64
#  12  EngagementLevel            10000 non-null  object
# dtypes: float64(3), int64(5), object(5)
# memory usage: 1015.8+ KB

# %%
mask = ((df['Gender'] == 'Male')
        & (df['Location'] == 'Europe')
        & (df['InGamePurchases'] == 1.0))
df[mask]
# Out:
#       PlayerID   Age Gender Location GameGenre  PlayTimeHours  \
# 30       22488  26.0   Male   Europe    Action      23.347913
# 39       38439  48.0   Male   Europe    Sports       8.759941
# 52       11149  41.0   Male   Europe    Sports       8.683196
# 63       45546  18.0   Male   Europe    Sports      17.287868
# 68        9158  46.0   Male   Europe    Sports      12.306317
# ...        ...   ...    ...      ...       ...            ...
# 9880     27701  33.0   Male   Europe    Sports       7.351962
# 9889     15514  41.0   Male   Europe    Action       0.965662
# 9907     26038  23.0   Male   Europe       RPG       9.154653
# 9930      9735  19.0   Male   Europe       RPG       7.825493
# 9948     48004  25.0   Male   Europe    Action      13.320361
#
#       InGamePurchases GameDifficulty  SessionsPerWeek  \
# 30                1.0         Medium               18
# 39                1.0         Medium                6
# 52                1.0           Hard                8
# 63                1.0           Easy                7
# 68                1.0         Medium               11
# ...               ...            ...              ...
# 9880              1.0           Hard                8
# 9889              1.0           Hard               17
# 9907              1.0           Hard                2
# 9930              1.0           Easy                1
# 9948              1.0           Easy               16
#
#       AvgSessionDurationMinutes  PlayerLevel  AchievementsUnlocked  \
# 30                           33           48                    45
# 39                           40           74                    47
# 52                          125           31                    23
# 63                          119           87                    41
# 68                          179           91                     4
# ...                         ...          ...                   ...
# 9880                         95           36                     5
# 9889                        104           32                    33
# 9907                         27           43                    34
# 9930                         22            8                    31
# 9948                         45            5                     0
#
#      EngagementLevel
# 30            Medium
# 39            Medium
# 52            Medium
# 63            Medium
# 68              High
# ...              ...
# 9880          Medium
# 9889            High
# 9907             Low
# 9930             Low
# 9948          Medium
#
# [299 rows x 13 columns]

# %%
mask = ((df['Age'] < 18) &
        (df['PlayTimeHours'] > 10))

df[mask]
# Out:
#       PlayerID   Age  Gender Location   GameGenre  PlayTimeHours  \
# 25       24898  15.0    Male     Asia      Sports      12.376600
# 64       34210  16.0  Female   Europe         RPG      12.106891
# 72       22234  17.0  Female   Europe      Sports      18.473853
# 133      19489  17.0    Male      NaN    Strategy      23.178396
# 154      43046  16.0  Female      USA      Sports      13.464307
# ...        ...   ...     ...      ...         ...            ...
# 9959     44285  15.0    Male     Asia      Action      21.506080
# 9982     33227  16.0    Male      USA  Simulation      11.236814
# 9984     24634  15.0  Female   Europe    Strategy      16.071099
# 9987      9950  17.0    Male     Asia         RPG      17.512651
# 9998     42490  16.0    Male   Europe    Strategy      17.111949
#
#       InGamePurchases GameDifficulty  SessionsPerWeek  \
# 25                0.0           Easy                2
# 64                0.0           Hard                1
# 72                0.0           Easy               12
# 133               0.0            NaN                4
# 154               0.0           Hard                3
# ...               ...            ...              ...
# 9959              0.0           Easy               15
# 9982              1.0           Easy                9
# 9984              0.0           Easy               14
# 9987              0.0           Easy               14
# 9998              0.0         Medium                6
#
#       AvgSessionDurationMinutes  PlayerLevel  AchievementsUnlocked  \
# 25                          100           49                    43
# 64                           85           78                     4
# 72                           11           50                    25
# 133                         136           36                    39
# 154                          26           20                    12
# ...                         ...          ...                   ...
# 9959                        132           35                    34
# 9982                         85           85                    26
# 9984                        141           16                    28
# 9987                         84           36                    18
# 9998                         70           24                    32
#
#      EngagementLevel
# 25              High
# 64               Low
# 72               Low
# 133           Medium
# 154              Low
# ...              ...
# 9959            High
# 9982          Medium
# 9984            High
# 9987          Medium
# 9998          Medium
#
# [453 rows x 13 columns]

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, [-1]]
X
y
# Out:
#       PlayerID   Age  Gender Location   GameGenre  PlayTimeHours  \
# 0        35900  37.0    Male    Other    Strategy      23.929404
# 1        27085  25.0    Male      NaN      Action      22.755168
# 2        39595  24.0  Female   Europe  Simulation      19.505292
# 3        37440  26.0  Female   Europe         RPG      11.009645
# 4        22882  17.0  Female      USA         RPG       0.581039
# ...        ...   ...     ...      ...         ...            ...
# 9995     42828  22.0  Female      USA      Sports      21.336213
# 9996     18169  21.0    Male   Europe    Strategy       6.158520
# 9997     22094  43.0    Male      USA      Action      22.628880
# 9998     42490  16.0    Male   Europe    Strategy      17.111949
# 9999     42839  45.0    Male    Other  Simulation      22.067866
#
#       InGamePurchases GameDifficulty  SessionsPerWeek  \
# 0                 NaN           Hard                3
# 1                 1.0           Easy               14
# 2                 0.0           Hard                3
# 3                 NaN            NaN                3
# 4                 1.0         Medium                5
# ...               ...            ...              ...
# 9995              0.0         Medium               13
# 9996              0.0           Easy                4
# 9997              0.0           Easy                4
# 9998              0.0         Medium                6
# 9999              1.0           Easy                4
#
#       AvgSessionDurationMinutes  PlayerLevel  AchievementsUnlocked
# 0                           124           99                    18
# 1                            84           84                    12
# 2                           172            9                    18
# 3                            83           36                    43
# 4                           163            9                    24
# ...                         ...          ...                   ...
# 9995                         58           74                    15
# 9996                         10           77                    27
# 9997                        161           66                    46
# 9998                         70           24                    32
# 9999                        131           10                    24
#
# [10000 rows x 12 columns]
#      EngagementLevel
# 0             Medium
# 1             Medium
# 2             Medium
# 3                Low
# 4             Medium
# ...              ...
# 9995          Medium
# 9996             Low
# 9997          Medium
# 9998          Medium
# 9999          Medium
#
# [10000 rows x 1 columns]

# %%
df.isnull().sum().sum()
# Out:
# np.int64(3337)

# %%
from sklearn.model_selection import train_test_split

# %%
train_set, test_set = train_test_split(df, test_size=0.2, random_state=42)
train_set
test_set
# Out:
#       PlayerID   Age  Gender Location   GameGenre  PlayTimeHours  \
# 9254     43413  34.0  Female     Asia  Simulation      15.777862
# 1561     43503  41.0    Male      USA    Strategy       3.044182
# 1670     29028  48.0  Female      USA  Simulation       0.585613
# 6087     15998  19.0    Male   Europe      Action       6.194149
# 6669     21496  38.0    Male   Europe         RPG      21.610488
# ...        ...   ...     ...      ...         ...            ...
# 5734     37171  21.0    Male   Europe         RPG       2.698920
# 5191     14643  48.0    Male      USA      Sports      20.508777
# 5390     36561  19.0    Male     Asia      Action       9.480399
# 860      20846  28.0    Male   Europe    Strategy       7.895527
# 7270     25964  15.0    Male   Europe      Action      13.401741
#
#       InGamePurchases GameDifficulty  SessionsPerWeek  \
# 9254              0.0         Medium                5
# 1561              0.0         Medium                7
# 1670              0.0         Medium               16
# 6087              0.0           Easy                6
# 6669              NaN           Easy               14
# ...               ...            ...              ...
# 5734              0.0           Hard                4
# 5191              1.0         Medium               12
# 5390              0.0           Easy                4
# 860               0.0         Medium                4
# 7270              NaN         Medium                6
#
#       AvgSessionDurationMinutes  PlayerLevel  AchievementsUnlocked  \
# 9254                         76           80                    33
# 1561                         73           34                     5
# 1670                        163           44                     3
# 6087                         87           26                    33
# 6669                        116           39                    14
# ...                         ...          ...                   ...
# 5734                        179            1                    12
# 5191                         42           64                    49
# 5390                         32           31                    43
# 860                          27           99                    48
# 7270                         77           11                    20
#
#      EngagementLevel
# 9254          Medium
# 1561          Medium
# 1670            High
# 6087          Medium
# 6669            High
# ...              ...
# 5734          Medium
# 5191          Medium
# 5390          Medium
# 860           Medium
# 7270          Medium
#
# [8000 rows x 13 columns]
#       PlayerID   Age  Gender Location   GameGenre  PlayTimeHours  \
# 6252     45359  38.0    Male    Other    Strategy      13.585655
# 4684     36195  37.0  Female   Europe  Simulation       3.650090
# 1731     14118  31.0  Female     Asia      Sports      11.610198
# 4742     28448   NaN    Male     Asia  Simulation      21.214511
# 4521     35751  20.0    Male      NaN    Strategy       0.235298
# ...        ...   ...     ...      ...         ...            ...
# 6412     45829   NaN  Female      USA  Simulation       7.874463
# 8285     29985  31.0    Male   Europe      Sports      11.491252
# 7853     21634  24.0    Male   Europe      Action      18.789856
# 1095     46243  23.0    Male     Asia  Simulation      22.076684
# 6929     40465  22.0    Male   Europe  Simulation      13.353841
#
#       InGamePurchases GameDifficulty  SessionsPerWeek  \
# 6252              0.0            NaN               18
# 4684              0.0           Easy               17
# 1731              0.0         Medium                0
# 4742              0.0           Easy                3
# 4521              1.0           Easy                1
# ...               ...            ...              ...
# 6412              1.0           Hard                6
# 8285              0.0           Easy               18
# 7853              0.0           Hard                4
# 1095              0.0            NaN               14
# 6929              1.0           Easy               15
#
#       AvgSessionDurationMinutes  PlayerLevel  AchievementsUnlocked  \
# 6252                        141           96                    19
# 4684                         12           22                     2
# 1731                         68           92                    29
# 4742                         21           29                     7
# 4521                        161           85                    15
# ...                         ...          ...                   ...
# 6412                         51           67                     2
# 8285                        108           83                     2
# 7853                        169           66                    13
# 1095                        107           10                    40
# 6929                         19           21                    29
#
#      EngagementLevel
# 6252            High
# 4684             Low
# 1731             Low
# 4742             Low
# 4521             Low
# ...              ...
# 6412             Low
# 8285            High
# 7853          Medium
# 1095            High
# 6929             Low
#
# [2000 rows x 13 columns]

# %%
y_train = train_set.iloc[:, [-1]]
y_train
y_train.value_counts()
# Out:
#      EngagementLevel
# 9254          Medium
# 1561          Medium
# 1670            High
# 6087          Medium
# 6669            High
# ...              ...
# 5734          Medium
# 5191          Medium
# 5390          Medium
# 860           Medium
# 7270          Medium
#
# [8000 rows x 1 columns]
# EngagementLevel
# Medium             3983
# Low                2021
# High               1996
# Name: count, dtype: int64

# %%
df_copy = df.copy()

# %%
# df_copy['Age'].fillna(df_copy['Age'].mean()).isnull().sum()

# %%
test_set = test_set.dropna(subset=['Age'])
test_set['Age'].isna().sum()
test_set['Age'].sum()
# Out:
# np.int64(0)
# np.float64(58511.0)
