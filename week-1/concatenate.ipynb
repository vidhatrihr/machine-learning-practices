# %%
import pandas as pd

# %%
temp_data = pd.DataFrame({
    'date': ['01-02-2026', '02-02-2026', '03-02-2026', '04-02-2026', '05-02-2026'],
    'temp': [23, 25, 17.7, 20.6, 24.5]
}, index=range(30, 35))

temp_data
# Out:
#           date  temp
# 30  01-02-2026  23.0
# 31  02-02-2026  25.0
# 32  03-02-2026  17.7
# 33  04-02-2026  20.6
# 34  05-02-2026  24.5

# %%
rainfall_data = pd.DataFrame({
    'date': ['01-02-2026', '02-02-2026', '03-02-2026', '04-02-2026', '05-02-2026',],
    'rainfall': [0, 2, 3.2, 1, 2]
}, index=range(50, 55))

rainfall_data
# Out:
#           date  rainfall
# 50  01-02-2026       0.0
# 51  02-02-2026       2.0
# 52  03-02-2026       3.2
# 53  04-02-2026       1.0
# 54  05-02-2026       2.0

# %%
pd.concat([temp_data, rainfall_data])  # By default vertical (axis=0)
# Out:
#           date  temp  rainfall
# 30  01-02-2026  23.0       NaN
# 31  02-02-2026  25.0       NaN
# 32  03-02-2026  17.7       NaN
# 33  04-02-2026  20.6       NaN
# 34  05-02-2026  24.5       NaN
# 50  01-02-2026   NaN       0.0
# 51  02-02-2026   NaN       2.0
# 52  03-02-2026   NaN       3.2
# 53  04-02-2026   NaN       1.0
# 54  05-02-2026   NaN       2.0

# %%
pd.concat([temp_data, rainfall_data], axis=1)  # Horizontal contact
# Out:
#           date  temp        date  rainfall
# 30  01-02-2026  23.0         NaN       NaN
# 31  02-02-2026  25.0         NaN       NaN
# 32  03-02-2026  17.7         NaN       NaN
# 33  04-02-2026  20.6         NaN       NaN
# 34  05-02-2026  24.5         NaN       NaN
# 50         NaN   NaN  01-02-2026       0.0
# 51         NaN   NaN  02-02-2026       2.0
# 52         NaN   NaN  03-02-2026       3.2
# 53         NaN   NaN  04-02-2026       1.0
# 54         NaN   NaN  05-02-2026       2.0

# %%
pd.concat([temp_data, rainfall_data], ignore_index=True)
# Out:
#          date  temp  rainfall
# 0  01-02-2026  23.0       NaN
# 1  02-02-2026  25.0       NaN
# 2  03-02-2026  17.7       NaN
# 3  04-02-2026  20.6       NaN
# 4  05-02-2026  24.5       NaN
# 5  01-02-2026   NaN       0.0
# 6  02-02-2026   NaN       2.0
# 7  03-02-2026   NaN       3.2
# 8  04-02-2026   NaN       1.0
# 9  05-02-2026   NaN       2.0

# %% [markdown]
# ## Join

# %%
pd.concat([temp_data, rainfall_data], axis=0, join='inner')  # Displays rows of common column
# Out:
#           date
# 30  01-02-2026
# 31  02-02-2026
# 32  03-02-2026
# 33  04-02-2026
# 34  05-02-2026
# 50  01-02-2026
# 51  02-02-2026
# 52  03-02-2026
# 53  04-02-2026
# 54  05-02-2026

# %%
pd.concat([temp_data, rainfall_data], axis=0, join='outer')  # Displays rows of all the columns
# Out:
#           date  temp  rainfall
# 30  01-02-2026  23.0       NaN
# 31  02-02-2026  25.0       NaN
# 32  03-02-2026  17.7       NaN
# 33  04-02-2026  20.6       NaN
# 34  05-02-2026  24.5       NaN
# 50  01-02-2026   NaN       0.0
# 51  02-02-2026   NaN       2.0
# 52  03-02-2026   NaN       3.2
# 53  04-02-2026   NaN       1.0
# 54  05-02-2026   NaN       2.0

# %% [markdown]
# ## Keys

# %%
keyed_df = pd.concat([temp_data, rainfall_data], axis=0, keys=('Delhi', 'Chennai'))
keyed_df
# Out:
#                   date  temp  rainfall
# Delhi   30  01-02-2026  23.0       NaN
#         31  02-02-2026  25.0       NaN
#         32  03-02-2026  17.7       NaN
#         33  04-02-2026  20.6       NaN
#         34  05-02-2026  24.5       NaN
# Chennai 50  01-02-2026   NaN       0.0
#         51  02-02-2026   NaN       2.0
#         52  03-02-2026   NaN       3.2
#         53  04-02-2026   NaN       1.0
#         54  05-02-2026   NaN       2.0

# %%
# multi index
keyed_df.index
# Out:
# MultiIndex([(  'Delhi', 30),
#             (  'Delhi', 31),
#             (  'Delhi', 32),
#             (  'Delhi', 33),
#             (  'Delhi', 34),
#             ('Chennai', 50),
#             ('Chennai', 51),
#             ('Chennai', 52),
#             ('Chennai', 53),
#             ('Chennai', 54)],
#            )

# %%
keyed_df.loc[('Delhi')]
keyed_df.loc[('Delhi', 31)]
# Out:
#           date  temp  rainfall
# 30  01-02-2026  23.0       NaN
# 31  02-02-2026  25.0       NaN
# 32  03-02-2026  17.7       NaN
# 33  04-02-2026  20.6       NaN
# 34  05-02-2026  24.5       NaN
# date        02-02-2026
# temp              25.0
# rainfall           NaN
# Name: (Delhi, 31), dtype: object

# %%
keyed_df.loc[[('Delhi', 30), ('Chennai', 50)]]
# Out:
#                   date  temp  rainfall
# Delhi   30  01-02-2026  23.0       NaN
# Chennai 50  01-02-2026   NaN       0.0

# %%
keyed_df = pd.concat([temp_data, rainfall_data], axis=1, keys=('Delhi', 'Chennai'))
keyed_df
# Out:
#          Delhi           Chennai
#           date  temp        date rainfall
# 30  01-02-2026  23.0         NaN      NaN
# 31  02-02-2026  25.0         NaN      NaN
# 32  03-02-2026  17.7         NaN      NaN
# 33  04-02-2026  20.6         NaN      NaN
# 34  05-02-2026  24.5         NaN      NaN
# 50         NaN   NaN  01-02-2026      0.0
# 51         NaN   NaN  02-02-2026      2.0
# 52         NaN   NaN  03-02-2026      3.2
# 53         NaN   NaN  04-02-2026      1.0
# 54         NaN   NaN  05-02-2026      2.0

# %%
keyed_df['Delhi'] # column label
# Out:
#           date  temp
# 30  01-02-2026  23.0
# 31  02-02-2026  25.0
# 32  03-02-2026  17.7
# 33  04-02-2026  20.6
# 34  05-02-2026  24.5
# 50         NaN   NaN
# 51         NaN   NaN
# 52         NaN   NaN
# 53         NaN   NaN
# 54         NaN   NaN

# %%
type(keyed_df)
type(keyed_df['Chennai'])
type(keyed_df.loc[32])
# Out:
# pandas.core.frame.DataFrame
# pandas.core.frame.DataFrame
# pandas.core.series.Series

# %%
keyed_df.columns
# Out:
# MultiIndex([(  'Delhi',     'date'),
#             (  'Delhi',     'temp'),
#             ('Chennai',     'date'),
#             ('Chennai', 'rainfall')],
#            )

# %%
keyed_df[[('Delhi', 'date'), ('Chennai', 'date')]]
# Out:
#          Delhi     Chennai
#           date        date
# 30  01-02-2026         NaN
# 31  02-02-2026         NaN
# 32  03-02-2026         NaN
# 33  04-02-2026         NaN
# 34  05-02-2026         NaN
# 50         NaN  01-02-2026
# 51         NaN  02-02-2026
# 52         NaN  03-02-2026
# 53         NaN  04-02-2026
# 54         NaN  05-02-2026
